# %% [markdown]
# 3, 0.03:
# Bridged Clustering Errors Average: 9.501621667301292
# KNN Regression Errors Average: 11.49141390093326
# Ratio = 0.826845
#
# 3, 0.05:
# Bridged Clustering Errors Average: 8.946369550624581
# KNN Regression Errors Average: 9.974643937706702
# Ratio = 0.896911
#
# 3, 0.07:
# Bridged Clustering Errors Average: 8.449947452526146
# KNN Regression Errors Average: 8.950710643650078
# Ratio = 0.944053
#
# 3, 0.10:
# Bridged Clustering Errors Average: 9.6332059835485
# KNN Regression Errors Average: 9.171219885635653
# Ratio = 1.050373
#
# 4, 0.03:
# Bridged Clustering Errors Average: 10.051660438954555
# KNN Regression Errors Average: 11.075878743537277
# Ratio = 0.907527
#
# 4, 0.05:
# Bridged Clustering Errors Average: 9.48946419099483
# KNN Regression Errors Average: 9.66331376380685
# Ratio = 0.98306
#
# 4, 0.07:
# Bridged Clustering Errors Average: 8.82119466166174
# KNN Regression Errors Average: 8.89629535376617
# Ratio = 0.99154
#
# 4, 0.10:
# Bridged Clustering Errors Average: 10.248446867551282
# KNN Regression Errors Average: 9.43825261957817
# Ratio = 1.08608
#
# 5, 0.03:
# Bridged Clustering Errors Average: 9.715016939749638
# KNN Regression Errors Average: 10.514374104556119
# Ratio = 0.92374
#
# 5, 0.05:
# Bridged Clustering Errors Average: 9.688781434969595
# KNN Regression Errors Average: 9.659334884327492
# Ratio = 1.00306
#
# 5, 0.07:
# Bridged Clustering Errors Average: 8.928488220787887
# KNN Regression Errors Average: 8.769030234484177
# Ratio = 1.01815
#
# 5, 0.10:
# Bridged Clustering Errors Average: 9.708445049386857
# KNN Regression Errors Average: 8.984811054297252
# Ratio = 1.08103
#
# 6, 0.03:
# Bridged Clustering Errors Average: 10.016588761246599
# KNN Regression Errors Average: 10.099060446444913
# Ratio = 0.99388
#
# 6, 0.05:
# Bridged Clustering Errors Average: 9.309517884224741
# KNN Regression Errors Average: 9.258884003607704
# Ratio = 1.00547
#
# 6, 0.07:
# Bridged Clustering Errors Average: 9.238077200345293
# KNN Regression Errors Average: 8.943758247664295
# Ratio = 1.03306
#
# 6, 0.10:
# Bridged Clustering Errors Average: 9.587123135037585
# KNN Regression Errors Average: 8.919155448791425
# Ratio = 1.07489

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ratios = np.array([
    [0.826845, 0.896911, 0.944053, 1.050373],
    [0.907527, 0.98306, 0.99154, 1.08608],
    [0.92374, 1.00306, 1.01815, 1.08103],
    [0.99388, 1.00547, 1.03306, 1.07489]  # np.nan for missing value
])

# Create a heatmap with clearer color distinction between values over and under 1
plt.figure(figsize=(8, 6))
sns.heatmap(ratios, annot=True, fmt=".5f", cmap="seismic", cbar=True, 
            xticklabels=[0.03, 0.05, 0.07, 0.10], yticklabels=[3, 4, 5, 6], 
            center=1)  # Set the center to 1 for better color distinction

plt.title("BKM Loss / KNN Loss")
plt.xlabel("%supervised")
plt.ylabel("n_clusters")

# Show the heatmap
plt.show()

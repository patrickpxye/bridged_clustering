# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Patch

# Define parameters
clusters = np.array([3, 4, 5, 6])  # Number of Clusters
sample_sizes = np.array([30, 40, 50, 60, 70, 80, 90, 100])  # Sample Size per Cluster
models = ['Bridged Clustering', 'KNN Regression', 'MeanTeacher', 'Graph Convolutional Network']

# Results data: shape (4, 8, 3)
results = np.array([
    [
        [8.12830996, 7.76116014, 7.31963682],
        [8.32398678, 8.04808763, 7.6471529 ],
        [9.07803648, 12.06358731, 10.14333534],
        [8.10669162, 8.67252594, 8.42085457],
        [8.17779553, 10.45346656, 9.88628006],
        [10.48992222, 11.51144743, 10.74252796],
        [9.97294629, 11.36341849, 10.46478939],
        [9.92900193, 15.69381566, 11.24783325]
    ],
    [
        [9.34587965, 8.44176206, 7.65359354],
        [8.80714676, 9.81630232, 9.19061852],
        [9.39744062, 9.62772029, 8.62230301],
        [8.71591215, 9.25938046, 8.43917274],
        [9.69282264, 10.42133741, 9.48373127],
        [10.85851376, 11.5250129, 10.19429588],
        [9.78447267, 11.30615577, 9.94626331],
        [10.54685862, 13.91778917, 10.76925087]
    ],
    [
        [9.14209249, 8.91533342, 8.10873413],
        [9.48574296, 10.00605664, 9.0281992 ],
        [9.86300076, 10.74797956, 8.85126972],
        [9.43306426, 9.94918457, 8.78964806],
        [10.10110278, 11.14454625, 9.71740627],
        [10.91643811, 12.13094018, 10.84386063],
        [10.53080709, 11.80268061, 10.29445934],
        [9.98969291, 14.53650383, 11.02061939]
    ],
    [
        [8.96277288, 9.89164284, 8.47749519],
        [10.28381532, 9.47095968, 8.45507717],
        [9.4004518, 10.70449158, 8.98950577],
        [10.32585393, 10.50758901, 8.87396908],
        [10.49112388, 10.86102218, 9.70707035],
        [10.81188341, 12.09598752, 10.70627689],
        [9.90198721, 11.841006,    10.15272236],
        [10.9963768,  14.06423722, 11.06033611]
    ]
])

# Compute inverted loss (1 / average loss)
inverted_results = 1.0 / results

# Create a meshgrid for sample sizes (x) and clusters (y)
X, Y = np.meshgrid(sample_sizes, clusters)

# Create 3D plot
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')

# Define a distinct color for each model
colors = ['C0', 'C1', 'C2']

# Plot a surface for each model's inverted loss data
for i, model in enumerate(models):
    # Extract Z data for the current model (shape 4 x 8)
    Z = inverted_results[:, :, i]
    surf = ax.plot_surface(X, Y, Z, color=colors[i], alpha=0.7,
                           edgecolor='k', rstride=1, cstride=1)
    # Scatter the original data points over the surface
    ax.scatter(X, Y, Z, color=colors[i], s=50)

# Set axis labels and title
ax.set_xlabel('Sample Size per Cluster')
ax.set_ylabel('Number of Clusters')
ax.set_zlabel('Inverted Loss (1 / Avg Loss)')
ax.set_title('3D Manifold Visualization of Inverted Loss per Model')

# Create custom legend handles
legend_elements = [Patch(facecolor=colors[i], edgecolor='k', label=models[i]) for i in range(len(models))]
ax.legend(handles=legend_elements, loc='upper left')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
clusters = [3, 4, 5, 6]  # Number of Clusters for each subplot
sample_sizes = [30, 40, 50, 60, 70, 80, 90, 100]  # Sample Size per Cluster
models = ['Bridged Clustering', 'KNN Regression', 'MeanTeacher']

# Original results data: shape (4, 8, 3) corresponding to 
# [number of clusters, sample size per cluster, model]
results = np.array([
    [
        [8.12830996, 7.76116014, 7.31963682],
        [8.32398678, 8.04808763, 7.6471529],
        [9.07803648, 12.06358731, 10.14333534],
        [8.10669162, 8.67252594, 8.42085457],
        [8.17779553, 10.45346656, 9.88628006],
        [10.48992222, 11.51144743, 10.74252796],
        [9.97294629, 11.36341849, 10.46478939],
        [9.92900193, 15.69381566, 11.24783325]
    ],
    [
        [9.34587965, 8.44176206, 7.65359354],
        [8.80714676, 9.81630232, 9.19061852],
        [9.39744062, 9.62772029, 8.62230301],
        [8.71591215, 9.25938046, 8.43917274],
        [9.69282264, 10.42133741, 9.48373127],
        [10.85851376, 11.5250129, 10.19429588],
        [9.78447267, 11.30615577, 9.94626331],
        [10.54685862, 13.91778917, 10.76925087]
    ],
    [
        [9.14209249, 8.91533342, 8.10873413],
        [9.48574296, 10.00605664, 9.0281992],
        [9.86300076, 10.74797956, 8.85126972],
        [9.43306426, 9.94918457, 8.78964806],
        [10.10110278, 11.14454625, 9.71740627],
        [10.91643811, 12.13094018, 10.84386063],
        [10.53080709, 11.80268061, 10.29445934],
        [9.98969291, 14.53650383, 11.02061939]
    ],
    [
        [8.96277288, 9.89164284, 8.47749519],
        [10.28381532, 9.47095968, 8.45507717],
        [9.4004518, 10.70449158, 8.98950577],
        [10.32585393, 10.50758901, 8.87396908],
        [10.49112388, 10.86102218, 9.70707035],
        [10.81188341, 12.09598752, 10.70627689],
        [9.90198721, 11.841006,    10.15272236],
        [10.9963768,  14.06423722, 11.06033611]
    ]
])

# Compute the inverted loss (reciprocal of loss)
inverted_results = 1.0 / results

# Create a grid of subplots (2 rows x 2 columns)
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
axs = axs.flatten()

# Iterate over each Number of Clusters (subplots)
for i, cluster in enumerate(clusters):
    ax = axs[i]
    # Plot inverted loss for each model
    for j, model in enumerate(models):
        ax.plot(sample_sizes, inverted_results[i, :, j], marker='o', label=model)
    ax.set_title(f'Number of Clusters = {cluster}')
    ax.set_xlabel('Sample Size per Cluster')
    ax.set_ylabel('Inverted Loss (1 / Avg Loss)')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 66
#      64 # Plot inverted loss for each model
#      65 for j, model in enumerate(models):
# ---> 66     ax.plot(sample_sizes, inverted_results[i, :, j], marker='o', label=model)
#      67 ax.set_title(f'Number of Clusters = {cluster}')
#      68 ax.set_xlabel('Sample Size per Cluster')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %% [markdown]
# 30 trials each
#
# 1st dimension = Number of Clusters: [3, 4, 5, 6]
# 2nd dimension = Sample Size per Cluster: [30, 40, 50, 60, 70, 80, 90, 100]
# 3rd dimension = Model: [Bridged Clustering, KNN Regression, MeanTeacher]
#
# Results Matrix:
# [[[ 8.12830996  7.76116014  7.31963682]
#   [ 8.32398678  8.04808763  7.6471529 ]
#   [ 9.07803648 12.06358731 10.14333534]
#   [ 8.10669162  8.67252594  8.42085457]
#   [ 8.17779553 10.45346656  9.88628006]
#   [10.48992222 11.51144743 10.74252796]
#   [ 9.97294629 11.36341849 10.46478939]
#   [ 9.92900193 15.69381566 11.24783325]]
#
#  [[ 9.34587965  8.44176206  7.65359354]
#   [ 8.80714676  9.81630232  9.19061852]
#   [ 9.39744062  9.62772029  8.62230301]
#   [ 8.71591215  9.25938046  8.43917274]
#   [ 9.69282264 10.42133741  9.48373127]
#   [10.85851376 11.5250129  10.19429588]
#   [ 9.78447267 11.30615577  9.94626331]
#   [10.54685862 13.91778917 10.76925087]]
#
#  [[ 9.14209249  8.91533342  8.10873413]
#   [ 9.48574296 10.00605664  9.0281992 ]
#   [ 9.86300076 10.74797956  8.85126972]
#   [ 9.43306426  9.94918457  8.78964806]
#   [10.10110278 11.14454625  9.71740627]
#   [10.91643811 12.13094018 10.84386063]
#   [10.53080709 11.80268061 10.29445934]
#   [ 9.98969291 14.53650383 11.02061939]]
#
#  [[ 8.96277288  9.89164284  8.47749519]
#   [10.28381532  9.47095968  8.45507717]
#   [ 9.4004518  10.70449158  8.98950577]
#   [10.32585393 10.50758901  8.87396908]
#   [10.49112388 10.86102218  9.70707035]
#   [10.81188341 12.09598752 10.70627689]
#   [ 9.90198721 11.841006   10.15272236]
#   [10.9963768  14.06423722 11.06033611]]]
#
# Setup:
# Rows = Number of Clusters: [3, 4, 5, 6]
# Columns = Sample Size per Cluster: [30, 40, 50, 60, 70, 80, 90, 100]
#
# BKM to KNN Ratio Matrix:
# [[1.04730605 ,1.03428133 ,0.7525155  ,0.93475553 ,0.78230465 ,0.91126006 ,0.8776361  ,0.63266972],
#  [1.10710058 ,0.89719596 ,0.9760816  ,0.94130619 ,0.93009393 ,0.94216934 ,0.8654111  ,0.75779698],
#  [1.02543473 ,0.94800013 ,0.91766091 ,0.94812436 ,0.90637183 ,0.89988393 ,0.89223859 ,0.68721427],
#  [0.90609548 ,1.08582611 ,0.87817826 ,0.9827044  ,0.96594259 ,0.89384049 ,0.83624543 ,0.78186798]]
#
# BKM to MeanTeacher Ratio Matrix:
# [[1.11047995 ,1.08850796 ,0.89497549 ,0.96269227 ,0.82718631 ,0.97648545 ,0.95300019 ,0.88274797],
#  [1.22111001 ,0.95827574 ,1.08989914 ,1.03279224 ,1.02204737 ,1.06515584 ,0.98373353 ,0.97934933],
#  [1.12743769 ,1.0506794  ,1.11430349 ,1.07320159 ,1.03948549 ,1.00669296 ,1.02295873 ,0.90645476],
#  [1.05724305 ,1.21628876 ,1.04571397 ,1.16361166 ,1.08077139 ,1.00986398 ,0.97530365 ,0.99421724]]
